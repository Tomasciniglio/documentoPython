# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

rice_ven = pd.read_csv('co2.csv')
rice_ven
#
# Out:
#    country_name  year          value
# 0     Venezuela  1960   57069.521000
# 1     Venezuela  1961   51928.387000
# 2     Venezuela  1962   54106.585000
# 3     Venezuela  1963   56204.109000
# 4     Venezuela  1964   56603.812000
# 5     Venezuela  1965   60787.859000
# 6     Venezuela  1966   57029.184000
# 7     Venezuela  1967   65815.316000
# 8     Venezuela  1968   65635.633000
# 9     Venezuela  1969   68998.272000
# 10    Venezuela  1970   74561.111000
# 11    Venezuela  1971   62562.687000
# 12    Venezuela  1972   62577.355000
# 13    Venezuela  1973   66501.045000
# 14    Venezuela  1974   75133.163000
# 15    Venezuela  1975   63816.801000
# 16    Venezuela  1976   57344.546000
# 17    Venezuela  1977   63732.460000
# 18    Venezuela  1978   68690.244000
# 19    Venezuela  1979   76570.627000
# 20    Venezuela  1980   90802.254000
# 21    Venezuela  1981   91968.360000
# 22    Venezuela  1982   93405.824000
# 23    Venezuela  1983   93101.463000
# 24    Venezuela  1984   93218.807000
# 25    Venezuela  1985  101278.873000
# 26    Venezuela  1986  109529.623000
# 27    Venezuela  1987  110981.755000
# 28    Venezuela  1988  116097.220000
# 29    Venezuela  1989  108854.895000
# 30    Venezuela  1990  101630.000000
# 31    Venezuela  1991  100990.000000
# 32    Venezuela  1992  103110.000000
# 33    Venezuela  1993  107390.000000
# 34    Venezuela  1994  106530.000000
# 35    Venezuela  1995  114040.000000
# 36    Venezuela  1996  121840.000000
# 37    Venezuela  1997  127590.000000
# 38    Venezuela  1998  129300.000000
# 39    Venezuela  1999  125460.000000
# 40    Venezuela  2000  131520.000000
# 41    Venezuela  2001  135800.000000
# 42    Venezuela  2002  140750.000000
# 43    Venezuela  2003  135770.004272
# 44    Venezuela  2004  139610.000610
# 45    Venezuela  2005  147380.004883
# 46    Venezuela  2006  147529.998779
# 47    Venezuela  2007  142389.999390
# 48    Venezuela  2008  151110.000610
# 49    Venezuela  2009  152589.996338
# 50    Venezuela  2010  164100.006104
# 51    Venezuela  2011  160039.993286
# 52    Venezuela  2012  181130.004883
# 53    Venezuela  2013  180429.992676
# 54    Venezuela  2014  179240.005493
# 55    Venezuela  2015  163130.004883
# 56    Venezuela  2016  151070.007324
# 57    Venezuela  2017  140820.007324
# 58    Venezuela  2018  132130.004883
# 59    Venezuela  2019  112339.996338

# %%
X = np.array(rice_ven['year'])
y = np.array(rice_ven['value'])
z = np.array([2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2032,2042,2052])
plt.scatter(X,y,label='data', color='red')
plt.title('Pronostico de Co2')

regresion_lineal = linear_model.LinearRegression()
regresion_lineal.fit(X.reshape(-1,1),y)
#se imprimen los parametros 
print ('\nParametros del modelo de regresión lineal')
print('b (Pendiente) = '+str(regresion_lineal.coef_) + ', a (Punto de corte) =' + str(regresion_lineal.intercept_))
#
pronostico = regresion_lineal.predict(z.reshape(-1,1))

print('\nPronosticos')
for i in range(len(z)):
    print('Predicción para el año {0} = {1} '.format(z[i], pronostico[i]))
    
pronostico_entrenamiento  = regresion_lineal.predict(X.reshape(-1,1))
mse = mean_squared_error(y_true = y, y_pred = pronostico_entrenamiento)
rmse = np.sqrt(mse)
print('\nEvaluación de calidad de la regresión')
print('Error Cuadrático Medio (MSE) = '+str(rmse))
print('Raíz del Error Cuadrático Medio(RMSE) = ' +str(rmse))

r2=regresion_lineal.score(X.reshape(-1,1), y)
print('Coeficiente de determinación R2 = ' +str(r2))

plt.plot(X,pronostico_entrenamiento,label='data', color='orange')
plt.xlabel('year')
# Out:
# Parametros del modelo de regresión lineal
# b (Pendiente) = [2031.89375127], a (Punto de corte) =-3935758.1544908904
#
# Pronosticos
# Predicción para el año 2020 = 168667.22306485893
# Predicción para el año 2021 = 170699.11681612395
# Predicción para el año 2022 = 172731.01056738896
# Predicción para el año 2023 = 174762.90431865444
# Predicción para el año 2024 = 176794.79806991946
# Predicción para el año 2025 = 178826.69182118494
# Predicción para el año 2026 = 180858.58557244996
# Predicción para el año 2027 = 182890.47932371544
# Predicción para el año 2028 = 184922.37307498045
# Predicción para el año 2029 = 186954.26682624593
# Predicción para el año 2030 = 188986.16057751095
# Predicción para el año 2031 = 191018.05432877596
# Predicción para el año 2032 = 193049.94808004145
# Predicción para el año 2042 = 213368.88559269346
# Predicción para el año 2052 = 233687.82310534595
#
# Evaluación de calidad de la regresión
# Error Cuadrático Medio (MSE) = 12764.852706800855
# Raíz del Error Cuadrático Medio(RMSE) = 12764.852706800855
# Coeficiente de determinación R2 = 0.8837108460403243
# Text(0.5, 0, 'year')
